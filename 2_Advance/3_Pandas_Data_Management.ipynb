# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt  

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.head(5)
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# 0               False  Texas, United States 2023-06-16 13:44:15
# 1               False                Mexico 2023-01-14 13:18:07
# 2               False               Germany 2023-10-10 13:14:55
# 3               False  Texas, United States 2023-07-04 13:01:41
# 4               False                 Sudan 2023-08-07 14:29:36
#
#    job_no_degree_mention  job_health_insurance    job_country salary_rate  \
# 0                  False                 False  United States        None
# 1                  False                 False         Mexico        None
# 2                  False                 False        Germany        None
# 3                   True                 False  United States        None
# 4                  False                 False          Sudan        None
#
#    salary_year_avg  salary_hour_avg                  company_name  \
# 0              NaN              NaN          Boehringer Ingelheim
# 1              NaN              NaN    Hewlett Packard Enterprise
# 2              NaN              NaN      ALPHA Augmented Services
# 3              NaN              NaN  Southwest Research Institute
# 4              NaN              NaN               Kristina Daniel
#
#                                           job_skills  \
# 0                                               None
# 1  ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2  ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3  ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4  ['bash', 'python', 'oracle', 'aws', 'ansible',...
#
#                                      job_type_skills
# 0                                               None
# 1  {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2  {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3  {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4  {'cloud': ['oracle', 'aws'], 'other': ['ansibl...

# %%
df.tail()
# Out:
#           job_title_short                                          job_title  \
# 785736  Software Engineer                                    DevOps Engineer
# 785737       Data Analyst                                   CRM Data Analyst
# 785738   Business Analyst                     Commercial Analyst - Start Now
# 785739      Data Engineer  Principal Associate, Data Engineer (Remote-Eli...
# 785740  Software Engineer                                 AWS System Analyst
#
#                                job_location                    job_via  \
# 785736                            Singapura        melalui Trabajo.org
# 785737                   Bad Rodach, Jerman  melalui BeBee Deutschland
# 785738                             Malaysia           melalui Ricebowl
# 785739  Newark, New Jersey, Amerika Serikat        melalui Recruit.net
# 785740                                India             melalui Trigyn
#
#        job_schedule_type  job_work_from_home search_location  \
# 785736   Pekerjaan tetap               False       Singapore
# 785737   Pekerjaan tetap               False         Germany
# 785738   Pekerjaan tetap               False        Malaysia
# 785739   Pekerjaan tetap               False           Sudan
# 785740   Pekerjaan tetap               False           India
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 785736 2023-03-13 06:16:16                  False                 False
# 785737 2023-03-12 06:18:18                  False                 False
# 785738 2023-03-12 06:32:36                  False                 False
# 785739 2023-03-12 06:32:15                  False                 False
# 785740 2023-03-13 06:16:31                  False                 False
#
#        job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 785736   Singapore        None              NaN              NaN
# 785737     Germany        None              NaN              NaN
# 785738    Malaysia        None              NaN              NaN
# 785739       Sudan        None              NaN              NaN
# 785740       India        None              NaN              NaN
#
#                               company_name  \
# 785736  CAREERSTAR INTERNATIONAL PTE. LTD.
# 785737                    HABA FAMILYGROUP
# 785738               Lendlease Corporation
# 785739                         Capital One
# 785740                              Trigyn
#
#                                                job_skills  \
# 785736  ['bash', 'python', 'perl', 'linux', 'unix', 'k...
# 785737                     ['sas', 'sas', 'sql', 'excel']
# 785738                            ['powerpoint', 'excel']
# 785739  ['python', 'go', 'nosql', 'sql', 'mongo', 'she...
# 785740                                    ['aws', 'flow']
#
#                                           job_type_skills
# 785736  {'os': ['linux', 'unix'], 'other': ['kubernete...
# 785737  {'analyst_tools': ['sas', 'excel'], 'programmi...
# 785738         {'analyst_tools': ['powerpoint', 'excel']}
# 785739  {'cloud': ['aws', 'snowflake', 'azure', 'redsh...
# 785740              {'cloud': ['aws'], 'other': ['flow']}

# %%
df.sample(10)
# Out:
#              job_title_short  \
# 654027  Senior Data Engineer
# 364637          Data Analyst
# 582076     Software Engineer
# 677381  Senior Data Engineer
# 471733        Cloud Engineer
# 7076           Data Engineer
# 185050          Data Analyst
# 493488         Data Engineer
# 125540        Data Scientist
# 640821   Senior Data Analyst
#
#                                                 job_title  \
# 654027                               Senior Data Engineer
# 364637               Assistant Controller (Data Analysis)
# 582076                            Senior Backend Engineer
# 677381  Senior Principal Data Integration Engineer (Du...
# 471733                                 Governance Analyst
# 7076                       Azure Data Engineer/ Developer
# 185050                   Customer Experience Data Analyst
# 493488                                Staff Data Engineer
# 125540                               Chief Data Scientist
# 640821                                Senior Data Analyst
#
#                             job_location               job_via  \
# 654027             Tel Aviv-Yafo, Israel            via Comeet
# 364637                         Hong Kong       via Recruit.net
# 582076                           Austria  via Jobs Trabajo.org
# 677381              Utrecht, Netherlands            via Indeed
# 471733                           Ireland     via BeBee Ireland
# 7076          Chennai, Tamil Nadu, India          via LinkedIn
# 185050                          Pakistan          via LinkedIn
# 493488                          Anywhere          via LinkedIn
# 125540  Abu Dhabi - United Arab Emirates          via LinkedIn
# 640821                          Anywhere      via Startup Jobs
#
#        job_schedule_type  job_work_from_home         search_location  \
# 654027         Full-time               False                  Israel
# 364637         Full-time               False               Hong Kong
# 582076         Full-time               False                 Austria
# 677381         Full-time               False             Netherlands
# 471733         Full-time               False                 Ireland
# 7076           Full-time               False                   India
# 185050         Full-time               False                Pakistan
# 493488         Full-time                True  Florida, United States
# 125540         Full-time               False    United Arab Emirates
# 640821         Full-time                True                   India
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 654027 2023-02-07 10:37:58                  False                 False
# 364637 2023-01-11 23:33:56                  False                 False
# 582076 2023-09-22 09:45:18                   True                 False
# 677381 2023-07-18 10:39:44                   True                 False
# 471733 2023-05-29 14:23:55                   True                 False
# 7076   2023-12-14 13:11:02                   True                 False
# 185050 2023-11-06 16:08:00                   True                 False
# 493488 2023-12-29 11:08:11                  False                  True
# 125540 2023-09-15 08:42:21                  False                 False
# 640821 2023-06-12 12:29:28                   True                 False
#
#                  job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 654027                Israel        None              NaN              NaN
# 364637             Hong Kong        None              NaN              NaN
# 582076               Austria        None              NaN              NaN
# 677381           Netherlands        None              NaN              NaN
# 471733               Ireland        None              NaN              NaN
# 7076                   India        None              NaN              NaN
# 185050              Pakistan        None              NaN              NaN
# 493488         United States        None              NaN              NaN
# 125540  United Arab Emirates        None              NaN              NaN
# 640821                 India        None              NaN              NaN
#
#                                     company_name  \
# 654027                                   Immunai
# 364637                              Michael Page
# 582076                Square Peg Capital Pty Ltd
# 677381  Recruit2, Talent Acquisition Specialists
# 471733                           Barclay Simpson
# 7076                       Hexaware Technologies
# 185050                                 foodpanda
# 493488                              ServiceTitan
# 125540              The Prime Technology Systems
# 640821                                Demandbase
#
#                                                job_skills  \
# 654027  ['sql', 'python', 'java', 'nosql', 'mysql', 'p...
# 364637                                               None
# 582076                                           ['java']
# 677381  ['sql', 'python', 'java', 'c#', 'azure', 'aws'...
# 471733                                               None
# 7076    ['python', 'sql', 'scala', 'azure', 'databrick...
# 185050  ['sql', 'python', 'tableau', 'power bi', 'excel']
# 493488  ['python', 'java', 'scala', 'sql', 'snowflake'...
# 125540          ['sql', 'python', 'r', 'hadoop', 'spark']
# 640821                         ['python', 'sql', 'excel']
#
#                                           job_type_skills
# 654027  {'cloud': ['oracle', 'snowflake', 'redshift'],...
# 364637                                               None
# 582076                          {'programming': ['java']}
# 677381  {'cloud': ['azure', 'aws', 'ibm cloud'], 'libr...
# 471733                                               None
# 7076    {'cloud': ['azure', 'databricks'], 'libraries'...
# 185050  {'analyst_tools': ['tableau', 'power bi', 'exc...
# 493488  {'cloud': ['snowflake'], 'libraries': ['spark'...
# 125540  {'libraries': ['hadoop', 'spark'], 'programmin...
# 640821  {'analyst_tools': ['excel'], 'programming': ['...

# %%
# DataFrame Copy
df_original = df.copy()

# %% [markdown]
# # copy()

# %%
# Create new dataframe
df_altered = df_original

df_altered.loc[:5,'salary_year_avg']
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# Name: salary_year_avg, dtype: float64

# %%
# Calculating the median salary
median_salary = df_altered['salary_year_avg'].median()

# Filling the missing values with the median salary
df_altered['salary_year_avg'] = df_altered.loc[:,'salary_year_avg'].fillna(median_salary)

# %%
df_altered['salary_year_avg'] = df_altered['salary_year_avg'].fillna(median_salary)

# %%
df_altered.loc[:5,'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %%
df_original.loc[:5,'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %%
print('ID of df_original:               ', id(df_original))
print('ID of df_altered:                ', id(df_altered))
print('Are the two dataframes the same? ', id(df_original) == id(df_altered))
# Out:
# ID of df_original:                2795150339088
# ID of df_altered:                 2795150339088
# Are the two dataframes the same?  True

# %%
# Using copy()

df_original = df.copy()
df_altered = df_original.copy()

print('ID of df_original:               ', id(df_original))
print('ID of df_altered:                ', id(df_altered))
print('Are the two dataframes the same? ', id(df_original) == id(df_altered))
# Out:
# ID of df_original:                2795169526096
# ID of df_altered:                 2795169524496
# Are the two dataframes the same?  False
